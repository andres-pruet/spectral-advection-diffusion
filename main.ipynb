# %%
gpu = False # make sure this matches other 3 files
if gpu:
    import cupy as np
else:
    import numpy as np
from SpectralAdvectionDiffusion import *
import time
# Out:
# not using gpu
# not using gpu
# not using gpu

# %%
'''
Simulation parameters.
For information about the parameters, check the readme.
'''

# plotting parameters
plotting = 1

# grid setup
dx = 0.2 + 2/30
Lx = 24
Lz = 12
stop_time = .3
nsteps_per_second = 40*1/.3
D = 1
gamma = 1/2
c = 1/8

# initial conditions for C
source_location = np.array([12,4])
source_spread = 0.5
source_type = 'puff'
n_copies = 10

# obstacle parameters
obstacle = True
shape_params = np.array([16,4,1]) # should be centerx,centerz, radius for circle

# wind MFS parameters
uinf = 10
rs_wind = 0.2
rs_wind_int = 1.2
Ns_wind = 100
Nb_wind = 120

# concentration MFS parameters
rs_conc = 0.8
cutoff = 35
rs_conc_int = 1 - 2*dx
Nb_conc = 60
Ns_conc = 50
# Nb_conc_int = 60 # currently just using Nb_conc for this number
Ns_conc_int = 20
sigma = 0.9*dx

# %%
h = simulate(
    gpu,
    dx,
    Lx,
    Lz,
    stop_time,
    nsteps_per_second,
    D,
    gamma,
    c,

    # initial conditions for C
    n_copies,

    # obstacle parameters
    obstacle,
    shape_params,

    # wind MFS parameters
    uinf,
    rs_wind,
    rs_wind_int,
    Ns_wind,
    Nb_wind,

    # concentration MFS parameters
    rs_conc,
    cutoff,
    rs_conc_int,
    Nb_conc,
    Ns_conc,
    Ns_conc_int,
    sigma,
    )

# %%
sim_start = time.time()
h.run(source_location = source_location,
      source_spread = source_spread,
      source_type = source_type,
      plotting=plotting)
sim_end = time.time()
print(f'total runtime: {sim_end - sim_start}')
# Out:
# starting sim ...
# end of sim
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 sim_start = time.time()
# ----> 2 h.run(source_location = source_location,
#       3       source_spread = source_spread,
#       4       source_type = source_type,
#       5       plotting=plotting)
#       6 sim_end = time.time()
#       7 print(f'total runtime: {sim_end - sim_start}')
#
# File \\home.mines.edu\home\m10940463\adit\My Documents\Spectral Advection Diffusion\spectral-advection-diffusion\src\SpectralAdvectionDiffusion\simulate.py:319, in simulate.run(self, source_location, source_spread, source_type, plotting)
#     317     np.save(f'./data/plots/{self.sim_date}/zz',self.zz.get())
#     318 else:
# --> 319     os.mkdir(f'./data/plots/{self.sim_date}/')
#     320     np.save(f'./data/plots/{self.sim_date}/C_plots',C_plots)
#     321     np.save(f'./data/plots/{self.sim_date}/Cp_plots',Cp_plots)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './data/plots/2026-06-01--13_49_12/'

# %%
if obstacle:
    matlab_C_final = np.load('./data/C_final_obstacle.npy')
else:
    matlab_C_final = np.load('./data/C_final_no_obs.npy')
print(f'rel error in C final: {np.linalg.norm(matlab_C_final - h.C)/np.linalg.norm(matlab_C_final)}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 if obstacle:
# ----> 2     matlab_C_final = np.load('./data/C_final_obstacle.npy')
#       3 else:
#       4     matlab_C_final = np.load('./data/C_final_no_obs.npy')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_npyio_impl.py:455, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453     own_fid = False
#     454 else:
# --> 455     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456     own_fid = True
#     458 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/C_final_obstacle.npy'

# %%
# this will save a pickle object with simulation data, as well as display the simulation timestamp.
print('Save this timestamp for plotting:')
h.make_log()
